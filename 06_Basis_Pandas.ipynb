# %% [markdown]
# # Aufgabenblatt 6: Pandas
#
# importiere die folgenden Bibliotheken
# - pandas
# - numpy
# - random
# - string

# %%
import pandas as pd
import numpy as np
import random
import string

from tornado.escape import utf8

# %% [markdown]
# ## Aufgabe 1: Erstelle einen eigenen Dataframe
# ### a) Dataframe erstellen mit manueller Eingabe
#
# erstelle einen DataFrame `data_1a` mit den Kennzahlen:
# - Column `column_string_1` mit *'String_1', 'String_2', 'Stirng_3'*
# - Column `column_mix` mit *'rot', 'rot', 'blau'*
# - Column `column_int` mit *1, 2, 2002*
# - Column `column_float` mit *1.5, 1.7, 1.9*

# %%
data_1a = pd.DataFrame({
    "column_string_1": ["String_1", "String_2", "String_3"],
    "column_mix": ["rot", "rot", "blau"],
    "column_int": [1, 2, 2002],
    "column_float": [1.5, 1.7, 1.9]
})
data_1a
# Out:
#   column_string_1 column_mix  column_int  column_float
# 0        String_1        rot           1           1.5
# 1        String_2        rot           2           1.7
# 2        String_3       blau        2002           1.9

# %% [markdown]
# ### b) Dateframe erstellen mit zufälligen und automatisch hinzugefügten Werten
#
# Erstelle einen Dataframe `data_1b`
# - der Dataframe hat `4` Columns mit jeweils `100` rows
# - der Dataframe hat die Column `column_string` mit *2 zufälligen Buchstaben pro Eintrag*
# - der Dataframe hat die Column `column_string_2` mit *gebe zufällig den Werten **rot** und **Blau** und
#     - der Wert rot soll 75% der Ausprägungen haben*
# - der Dataframe hat die Column `column_int` mit *zufälligen Werte im Bereich von 1 bis 10*
# - der Dataframe hat die Column `column_float` mit *zufällige Werte zwischen -100.00 und 100.00*
# <br> <br>*Tipp:*
# - random.choice, string.ascii_lowercase, uniform

# %%
data_1b = pd.DataFrame({
    "column_string": [''.join(random.choices(string.ascii_letters, k=2)) for _ in range(100)],
    "column_string_2": [random.choice(["rot", "rot", "rot", "blau"]) for _ in range(100)],
    "column_int": [random.randint(1, 10) for i in range(100)],
    "column_float": [random.uniform(-100, 100) for _ in range(100)],
})
data_1b
# Out:
#    column_string column_string_2  column_int  column_float
# 0             Sx             rot           4    -57.280156
# 1             Tj             rot           3    -67.094887
# 2             uK             rot          10    -94.073891
# 3             yb            blau           1    -54.456918
# 4             Ji             rot           3     -7.340326
# ..           ...             ...         ...           ...
# 95            Zv            blau           5    -85.278077
# 96            qN            blau          10    -55.239325
# 97            bJ             rot           1     91.435313
# 98            TY             rot           6     24.407883
# 99            Zz            blau           8    -30.501064
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Aufgabe 2: verbinden von DataFrames
#
# führe die beiden Dataframes `data_1a` und `data_1c` (alle Einträge) zusammen:
# - die join/merge Parameter Column ist gleich der Column int `column_int`,
# - verwende die Funktion `merge` und verwende für die Übungszwecke die verschiedenen Parameter:
#     1. gebe an aus welchem Dataframe kommt der Eintrag
#     2. wenn Columnnamen in beiden Dataframes vorkommen, sollen diese mit rechts und links erweitert werden
#
# <br> 101 rows × 8 columns

# %%
data_2 = pd.merge(
    data_1a,
    data_1b,
    on="column_int",
    how="outer",
    indicator=True,
    suffixes=("_A", "_B")
)

data_2
# Out:
#     column_string_1 column_mix  column_int  column_float_A column_string  \
# 0          String_1        rot           1             1.5            yb
# 1          String_1        rot           1             1.5            sF
# 2          String_1        rot           1             1.5            of
# 3          String_1        rot           1             1.5            rg
# 4          String_1        rot           1             1.5            EZ
# ..              ...        ...         ...             ...           ...
# 96              NaN        NaN          10             NaN            of
# 97              NaN        NaN          10             NaN            JC
# 98              NaN        NaN          10             NaN            zz
# 99              NaN        NaN          10             NaN            qN
# 100        String_3       blau        2002             1.9           NaN
#
#     column_string_2  column_float_B      _merge
# ...

# %% [markdown]
# ## Aufgabe 3: Datenimport  und Datenaufbereitung
# ### a) import von csv und excel Datein
# - importiere die csv Datei `2023`
# - bestimme die folgenden Parameter, sodass die Datei richtig gelesen werden kann:
#     - header
#     - seperator
#     - encoding

# %%
df_2023 = pd.read_csv(
    filepath_or_buffer="ressources/2023.csv",
    header=0,
    sep="\t",
    encoding="latin1"
)
df_2023

# \t für Tab als Seperator | Kein plan warum utf-8 (Standard) nicht funktioniert -> deshalb latin1
# Out:
#        Unnamed: 0 Getränk Region  Bestellnummer Rechnungsnummer  Kundennummer  \
# 0             205  Whisky    USA         5645.0    RE_2023_5645          16.0
# 1            8920  Whisky     EU         7994.0    RE_2023_7994         193.0
# 2            4116  Whisky    USA         3190.0    RE_2023_3190         126.0
# 3            1716  Whisky    USA          790.0     RE_2023_790         171.0
# 4           10901     Rum    USA         9975.0    RE_2023_9975          41.0
# ...           ...     ...    ...            ...             ...           ...
# 10922        5585  Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923        6251    Wein     EU         5325.0    RE_2023_5325         253.0
# 10924       10719  Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925        6407    Wein     EU         5481.0    RE_2023_5481          19.0
# 10926        3449  Whisky    USA         2523.0    RE_2023_2523         114.0
#
# ...

# %% [markdown]
# - importiere alle sheets aus der Excel_Datei Datei `before_2023` und speicher diese in einzelne DatFrames

# %%
df_2020 = pd.read_excel("ressources/before_2023.xlsx", sheet_name="2020")
df_2021 = pd.read_excel("ressources/before_2023.xlsx", sheet_name="2021")
df_2022 = pd.read_excel("ressources/before_2023.xlsx", sheet_name="2022")

df_2020.info()
df_2021.info()
df_2022.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2000 non-null   int64
#  1   Getränk            2000 non-null   str
#  2   Region             2000 non-null   str
#  3   Bestellnummer      2000 non-null   int64
#  4   Rechnungsnummer    2000 non-null   str
#  5   Kundennummer       2000 non-null   int64
#  6   Listenpreis        2000 non-null   float64
#  7   Rabatt in Prozent  2000 non-null   int64
#  8   Verkaufspreis      2000 non-null   float64
#  9   Rabatt Preis       2000 non-null   float64
#  10  Einkaufpreis       2000 non-null   float64
#  11  VK Peris in USD    2000 non-null   float64
# dtypes: float64(5), int64(4), str(3)
# memory usage: 187.6 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ...

# %% [markdown]
# ### b) Datenaufbereitung des Dataframes `2023`
# - schaue dir den neuen Datensatz an?
# -   beschreibe die Grösse des Datensatz (rows/records und columns)

# %%
df_2023.shape
# Out:
# (10927, 12)

# %% [markdown]
# - bestimme die mathematischen Werte wie z.B. `count`, `mmean`,`max`, `min`, `std`, `25%`, `50%` und `75%` des Datensatzes

# %%
df_2023.describe()
# Out:
#         Unnamed: 0  Bestellnummer  Kundennummer   Listenpreis  \
# count  10927.00000   10919.000000  10926.000000  10914.000000
# mean    5463.00000    5032.738896    149.100037    155.527156
# std     3154.49753    2906.072110     85.848563     43.382146
# min        0.00000       0.000000      1.000000     80.020000
# 25%     2731.50000    2516.500000     75.000000    118.160000
# 50%     5463.00000    5033.000000    149.000000    156.480000
# 75%     8194.50000    7548.500000    223.000000    192.832500
# max    10926.00000   10079.000000    299.000000    246.620000
#
#        Rabatt in Prozent  Rabatt Preis  VK Peris in USD
# count       10914.000000  10926.000000     10926.000000
# mean            1.273594     -2.014615       165.138933
# std             2.698154      4.491946        46.296567
# min             0.000000    -44.540000        71.000000
# 25%             0.000000      0.000000       125.230000
# 50%             0.000000      0.000000       165.845000
# ...

# %% [markdown]
# - erhalte die allgemeinen Informationen zum Datensatz wie z.B. Null-Werte, Datentypen, Columnnamen

# %%
df_2023.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10927 entries, 0 to 10926
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         10927 non-null  int64
#  1   Getränk            10912 non-null  str
#  2   Region             10924 non-null  str
#  3   Bestellnummer      10919 non-null  float64
#  4   Rechnungsnummer    10918 non-null  str
#  5   Kundennummer       10926 non-null  float64
#  6   Listenpreis        10914 non-null  float64
#  7   Rabatt in Prozent  10914 non-null  float64
#  8   Verkaufspreis      10914 non-null  str
#  9   Rabatt Preis       10926 non-null  float64
#  10  Einkaufpreis       10899 non-null  str
#  11  VK Peris in USD    10926 non-null  float64
# dtypes: float64(6), int64(1), str(5)
# memory usage: 1.0 MB

# %% [markdown]
# - schaue dir nur die esten 5 Einträge an

# %%
df_2023.head(5)
# Out:
#    Unnamed: 0 Getränk Region  Bestellnummer Rechnungsnummer  Kundennummer  \
# 0         205  Whisky    USA         5645.0    RE_2023_5645          16.0
# 1        8920  Whisky     EU         7994.0    RE_2023_7994         193.0
# 2        4116  Whisky    USA         3190.0    RE_2023_3190         126.0
# 3        1716  Whisky    USA          790.0     RE_2023_790         171.0
# 4       10901     Rum    USA         9975.0    RE_2023_9975          41.0
#
#    Listenpreis  Rabatt in Prozent Verkaufspreis  Rabatt Preis Einkaufpreis  \
# 0       128.95                5.0        128.95         -6.01       n96.71
# 1       132.81                5.0       n132.81         -6.64        99.61
# 2       216.21                0.0        216.21          0.00       162.16
# 3       172.13                0.0        172.13          0.00        129.1
# 4       128.73                0.0        128.73          0.00        96.55
#
#    VK Peris in USD
# 0           131.76
# 1           135.71
# ...

# %% [markdown]
# - die Column `Verkaufspreis` und `Einkaufpreis` sollen nur aus Zahlen bestehen und den Datentyp **float** besitzen
# - entferne die Buchstaben und erstelle einen neuen Dataframe mit Float Werten in den beiden Columns
#     - Fehler im Datenframe drüber sind:
#         - `Verkaufspreis` - row 1
#         - `Einkaufspreis` - row 0
# <br><br> **Tipp** manuelle Lösung mittels replace z.B.

# %%
df_2023_cleaned = df_2023.copy()
df_2023_cleaned["Verkaufspreis"] = df_2023_cleaned["Verkaufspreis"].astype(str).str.replace("n132.81", "132.81")
df_2023_cleaned["Einkaufpreis"] = df_2023_cleaned["Einkaufpreis"].astype(str).str.replace("n96.71", "96.71")

df_2023_cleaned["Verkaufspreis"] = pd.to_numeric(df_2023_cleaned["Verkaufspreis"], errors="coerce")
df_2023_cleaned["Einkaufpreis"] = pd.to_numeric(df_2023_cleaned["Einkaufpreis"], errors="coerce")
df_2023_cleaned.head()
# Out:
#    Unnamed: 0 Getränk Region  Bestellnummer Rechnungsnummer  Kundennummer  \
# 0         205  Whisky    USA         5645.0    RE_2023_5645          16.0
# 1        8920  Whisky     EU         7994.0    RE_2023_7994         193.0
# 2        4116  Whisky    USA         3190.0    RE_2023_3190         126.0
# 3        1716  Whisky    USA          790.0     RE_2023_790         171.0
# 4       10901     Rum    USA         9975.0    RE_2023_9975          41.0
#
#    Listenpreis  Rabatt in Prozent  Verkaufspreis  Rabatt Preis  Einkaufpreis  \
# 0       128.95                5.0         128.95         -6.01         96.71
# 1       132.81                5.0         132.81         -6.64         99.61
# 2       216.21                0.0         216.21          0.00        162.16
# 3       172.13                0.0         172.13          0.00        129.10
# 4       128.73                0.0         128.73          0.00         96.55
#
#    VK Peris in USD
# 0           131.76
# ...

# %% [markdown]
# **FORTGESCHRITTEN**
# - löse das Problem aus der Zelle vorher nun jeweils generisch
# - sodass die Buchstaben in den beiden Columns `Verkaufspreis` und `Einkaufpreis` entfernen kannst
# <br><br>
# **Tipp**
# - verwende u.a. regex
#     - r'\D' funktioniert nicht, weil es nur Zahlen zurücklässt
#     - '\d+' funktioniert nicht, weil nur Zahlen gelöscht werden

# %%
df_2023_cleaned = df_2023.copy()

price_cols = ["Verkaufspreis", "Einkaufpreis"]

df_2023_cleaned[price_cols] = (
    df_2023_cleaned[price_cols]
        .astype(str)
        .replace(r"[^0-9.\-]", "", regex=True)
        .apply(pd.to_numeric, errors="coerce")
)

df_2023_cleaned
# Out:
#        Unnamed: 0 Getränk Region  Bestellnummer Rechnungsnummer  Kundennummer  \
# 0             205  Whisky    USA         5645.0    RE_2023_5645          16.0
# 1            8920  Whisky     EU         7994.0    RE_2023_7994         193.0
# 2            4116  Whisky    USA         3190.0    RE_2023_3190         126.0
# 3            1716  Whisky    USA          790.0     RE_2023_790         171.0
# 4           10901     Rum    USA         9975.0    RE_2023_9975          41.0
# ...           ...     ...    ...            ...             ...           ...
# 10922        5585  Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923        6251    Wein     EU         5325.0    RE_2023_5325         253.0
# 10924       10719  Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925        6407    Wein     EU         5481.0    RE_2023_5481          19.0
# 10926        3449  Whisky    USA         2523.0    RE_2023_2523         114.0
#
# ...

# %% [markdown]
# Verändere alle Columnnamen. Es sollen die Colummnamen wie folgt angepasst werden:
# - Namen bestehen nur aus `Grossbuchtaben`
# - Leerzeichen werden durch `_` ersetzt
# - Sonderzeichen sollen angepasst werden in z.B. ö zu oe usw.
# - die Column `Unnamed: 0` wird gelöscht
# <br><br> rows 10.927

# %%
#for col in df_2023_cleaned.columns:
#    df_2023_cleaned[col] = df_2023_cleaned[col].astype(str)

df_2023_cleaned.drop("Unnamed: 0", axis=1, inplace=True)
df_2023_cleaned.columns = (df_2023_cleaned.columns.str.upper()
                           .str.replace(" ", "_")
                           .str.replace("Ä", "AE")
                           .str.replace("Ö", "OE")
                           .str.replace("Ü", "UE")
                           .str.replace("ß", "SS")
)

df_2023_cleaned
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0       Whisky    USA         5645.0    RE_2023_5645          16.0
# 1       Whisky     EU         7994.0    RE_2023_7994         193.0
# 2       Whisky    USA         3190.0    RE_2023_3190         126.0
# 3       Whisky    USA          790.0     RE_2023_790         171.0
# 4          Rum    USA         9975.0    RE_2023_9975          41.0
# ...        ...    ...            ...             ...           ...
# 10922   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923     Wein     EU         5325.0    RE_2023_5325         253.0
# 10924   Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925     Wein     EU         5481.0    RE_2023_5481          19.0
# 10926   Whisky    USA         2523.0    RE_2023_2523         114.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0           128.95                5.0         128.95         -6.01
# ...

# %% [markdown]
# - entferne die möglichen Doubletten in den Daten
# <br><br> rows 10.303

# %%
df_2023_cleaned.drop_duplicates(inplace=True)
df_2023_cleaned
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0       Whisky    USA         5645.0    RE_2023_5645          16.0
# 1       Whisky     EU         7994.0    RE_2023_7994         193.0
# 2       Whisky    USA         3190.0    RE_2023_3190         126.0
# 3       Whisky    USA          790.0     RE_2023_790         171.0
# 4          Rum    USA         9975.0    RE_2023_9975          41.0
# ...        ...    ...            ...             ...           ...
# 10922   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923     Wein     EU         5325.0    RE_2023_5325         253.0
# 10924   Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925     Wein     EU         5481.0    RE_2023_5481          19.0
# 10926   Whisky    USA         2523.0    RE_2023_2523         114.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0           128.95                5.0         128.95         -6.01
# ...

# %% [markdown]
# - entferne alle `null` rows
# - also Einträge auf row Ebene, welchen keinen Werte beinhalten -> in der gesamten Reihe
# <br><br> rows 10.302

# %%
df_2023_cleaned = df_2023_cleaned.dropna(how="all")
df_2023_cleaned
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0       Whisky    USA         5645.0    RE_2023_5645          16.0
# 1       Whisky     EU         7994.0    RE_2023_7994         193.0
# 2       Whisky    USA         3190.0    RE_2023_3190         126.0
# 3       Whisky    USA          790.0     RE_2023_790         171.0
# 4          Rum    USA         9975.0    RE_2023_9975          41.0
# ...        ...    ...            ...             ...           ...
# 10922   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923     Wein     EU         5325.0    RE_2023_5325         253.0
# 10924   Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925     Wein     EU         5481.0    RE_2023_5481          19.0
# 10926   Whisky    USA         2523.0    RE_2023_2523         114.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0           128.95                5.0         128.95         -6.01
# ...

# %% [markdown]
# - Gibt es in den Daten Einträge ohne Rechnungsnummer?
#     - Wenn ja wie viele Einträge sind es?

# %%
df_2023_cleaned["RECHNUNGSNUMMER"].isna().value_counts()
# Out:
# RECHNUNGSNUMMER
# False    10294
# True         8
# Name: count, dtype: int64

# %% [markdown]
# - Können Einträge ohne Rechnungsnummer nachträglich logisch abgeleitet werden aus den Daten
#     - wenn ja bitte befülle die Rechnungsnummerngebe die `NaN` Werte in einem eigenen Dataframe an,
#     - um die Frage der Befüllung der Rechnungsnummer besser zu beantworten gebe die `NaN` Werte in einem eigenen Dataframe an

# %%
#????? FRAGESTELLUNG ?????
df_rn = df_2023_cleaned[df_2023_cleaned["RECHNUNGSNUMMER"].isna()].copy()
df_rn
# Out:
#      GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 2171   Whisky    NaN        10078.0             NaN          54.0
# 2265   Whisky  Asien        10004.0             NaN          54.0
# 2684   Whisky    USA        10026.0             NaN          19.0
# 6205      Rum    USA        10074.0             NaN          27.0
# 6332   Whisky     EU        10039.0             NaN          24.0
# 6351      NaN     EU            NaN             NaN          49.0
# 6886   Whisky     EU        10008.0             NaN          42.0
# 7890   Whisky     EU        10050.0             NaN          42.0
#
#       LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 2171          NaN                5.0            NaN         -4.82
# 2265       148.21                5.0         148.21         -7.41
# 2684        82.51                NaN          82.51        -16.50
# 6205       131.09                0.0         131.09          0.00
# ...

# %% [markdown]
# - Was ist die Logik für die Wertbefüllung der Column `BESTELLNUMMER` und `RECHNUNGSNUMMER`

# %%
"""
Bestellnummer: ganzzahlig iterierender float??
Rechnungsnummer: RE_{JAHR}_{BESTELLNUMMER}
"""
# Out:
# '\nBestellnummer: ganzzahlig iterierender float??\nRechnungsnummer: RE_{JAHR}_{BESTELLNUMMER}\n'

# %% [markdown]
# - Daten die sowohl einen `NaN` Wert bei der `BESTELLNUMMER` als auch bei der `RECHNUNGSNUMMER` sollen aud dem Datensatz entfernt werden
# <br><br> rows 10.301

# %%
df_2023_cleaned = df_2023_cleaned.dropna(
    subset=["BESTELLNUMMER", "RECHNUNGSNUMMER"],
    how="all"
)

df_2023_cleaned
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0       Whisky    USA         5645.0    RE_2023_5645          16.0
# 1       Whisky     EU         7994.0    RE_2023_7994         193.0
# 2       Whisky    USA         3190.0    RE_2023_3190         126.0
# 3       Whisky    USA          790.0     RE_2023_790         171.0
# 4          Rum    USA         9975.0    RE_2023_9975          41.0
# ...        ...    ...            ...             ...           ...
# 10922   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923     Wein     EU         5325.0    RE_2023_5325         253.0
# 10924   Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925     Wein     EU         5481.0    RE_2023_5481          19.0
# 10926   Whisky    USA         2523.0    RE_2023_2523         114.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0           128.95                5.0         128.95         -6.01
# ...

# %% [markdown]
# - Befüllen der NaN Werte in der Column `Rechnungsnummer`

# %%
df_2023_cleaned["RECHNUNGSNUMMER"] = (
    df_2023_cleaned["RECHNUNGSNUMMER"]
    .fillna("RE_2023_" + df_2023_cleaned["BESTELLNUMMER"].astype(str))
)

df_2023_cleaned
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0       Whisky    USA         5645.0    RE_2023_5645          16.0
# 1       Whisky     EU         7994.0    RE_2023_7994         193.0
# 2       Whisky    USA         3190.0    RE_2023_3190         126.0
# 3       Whisky    USA          790.0     RE_2023_790         171.0
# 4          Rum    USA         9975.0    RE_2023_9975          41.0
# ...        ...    ...            ...             ...           ...
# 10922   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923     Wein     EU         5325.0    RE_2023_5325         253.0
# 10924   Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925     Wein     EU         5481.0    RE_2023_5481          19.0
# 10926   Whisky    USA         2523.0    RE_2023_2523         114.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0           128.95                5.0         128.95         -6.01
# ...

# %% [markdown]
# - Befüllen der NaN Werte in `Bestellnummer`
# <br> `TIPP:` apply und lambda

# %%
df_2023_cleaned["BESTELLNUMMER"] = (df_2023_cleaned["BESTELLNUMMER"]
                                    .fillna(df_2023_cleaned["RECHNUNGSNUMMER"].astype(str)
                                    .str.split("_").str[2]).astype(float))
df_2023_cleaned
#df_bn = df_2023_cleaned[df_2023_cleaned["BESTELLNUMMER"].isna()].copy()
#df_bn.head(10)
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0       Whisky    USA         5645.0    RE_2023_5645          16.0
# 1       Whisky     EU         7994.0    RE_2023_7994         193.0
# 2       Whisky    USA         3190.0    RE_2023_3190         126.0
# 3       Whisky    USA          790.0     RE_2023_790         171.0
# 4          Rum    USA         9975.0    RE_2023_9975          41.0
# ...        ...    ...            ...             ...           ...
# 10922   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923     Wein     EU         5325.0    RE_2023_5325         253.0
# 10924   Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925     Wein     EU         5481.0    RE_2023_5481          19.0
# 10926   Whisky    USA         2523.0    RE_2023_2523         114.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0           128.95                5.0         128.95         -6.01
# ...

# %% [markdown]
# `Rechnungsnummern müssen einmalig sein`
# - Aus diesem Grund sollen jeweils alle gleichen Rechnungsnummern aus dem Datensatz entfernt werden
# - Erstelle hierfür einen neuen Dataframe `data_2023_unique`
# <br><br> rows 10.079

# %%
data_2023_unique = df_2023_cleaned.drop_duplicates(subset="RECHNUNGSNUMMER")
data_2023_unique
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0       Whisky    USA         5645.0    RE_2023_5645          16.0
# 1       Whisky     EU         7994.0    RE_2023_7994         193.0
# 2       Whisky    USA         3190.0    RE_2023_3190         126.0
# 3       Whisky    USA          790.0     RE_2023_790         171.0
# 4          Rum    USA         9975.0    RE_2023_9975          41.0
# ...        ...    ...            ...             ...           ...
# 10922   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923     Wein     EU         5325.0    RE_2023_5325         253.0
# 10924   Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925     Wein     EU         5481.0    RE_2023_5481          19.0
# 10926   Whisky    USA         2523.0    RE_2023_2523         114.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0           128.95                5.0         128.95         -6.01
# ...

# %% [markdown]
# - befülle die NaN Werte in `RABATT_IN_PROZENT` mit den richtigen Prozenten
#     - Berechnung ergibt sich aus `LISTENPREIS` und `VERKAUFSPREIS`

# %%
data_2023_unique["RABATT_IN_PROZENT"] = data_2023_unique["RABATT_IN_PROZENT"].fillna((data_2023_unique["LISTENPREIS"] - data_2023_unique["VERKAUFSPREIS"]) / data_2023_unique["LISTENPREIS"]  * 100).astype(float)

data_2023_unique
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0       Whisky    USA         5645.0    RE_2023_5645          16.0
# 1       Whisky     EU         7994.0    RE_2023_7994         193.0
# 2       Whisky    USA         3190.0    RE_2023_3190         126.0
# 3       Whisky    USA          790.0     RE_2023_790         171.0
# 4          Rum    USA         9975.0    RE_2023_9975          41.0
# ...        ...    ...            ...             ...           ...
# 10922   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923     Wein     EU         5325.0    RE_2023_5325         253.0
# 10924   Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925     Wein     EU         5481.0    RE_2023_5481          19.0
# 10926   Whisky    USA         2523.0    RE_2023_2523         114.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0           128.95                5.0         128.95         -6.01
# ...

# %% [markdown]
# - befülle die restlichen Werte von `RABATT_IN_PROZENT` mit der Zahl `0`

# %%
data_2023_unique["RABATT_IN_PROZENT"] = data_2023_unique["RABATT_IN_PROZENT"].fillna(0.0).astype(float)
data_2023_unique
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0       Whisky    USA         5645.0    RE_2023_5645          16.0
# 1       Whisky     EU         7994.0    RE_2023_7994         193.0
# 2       Whisky    USA         3190.0    RE_2023_3190         126.0
# 3       Whisky    USA          790.0     RE_2023_790         171.0
# 4          Rum    USA         9975.0    RE_2023_9975          41.0
# ...        ...    ...            ...             ...           ...
# 10922   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923     Wein     EU         5325.0    RE_2023_5325         253.0
# 10924   Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925     Wein     EU         5481.0    RE_2023_5481          19.0
# 10926   Whisky    USA         2523.0    RE_2023_2523         114.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0           128.95                5.0         128.95         -6.01
# ...

# %% [markdown]
# - befülle die NaN Werte in der Column `LISTENPREIS` mit dem Mittelwert der Column

# %%
data_2023_unique["LISTENPREIS"] = data_2023_unique["LISTENPREIS"].fillna(data_2023_unique["LISTENPREIS"].median())
data_2023_unique
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0       Whisky    USA         5645.0    RE_2023_5645          16.0
# 1       Whisky     EU         7994.0    RE_2023_7994         193.0
# 2       Whisky    USA         3190.0    RE_2023_3190         126.0
# 3       Whisky    USA          790.0     RE_2023_790         171.0
# 4          Rum    USA         9975.0    RE_2023_9975          41.0
# ...        ...    ...            ...             ...           ...
# 10922   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923     Wein     EU         5325.0    RE_2023_5325         253.0
# 10924   Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925     Wein     EU         5481.0    RE_2023_5481          19.0
# 10926   Whisky    USA         2523.0    RE_2023_2523         114.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0           128.95                5.0         128.95         -6.01
# ...

# %% [markdown]
# - befülle die NaN Werte mit dem `vorherigen` nicht NaN-Wert in der Column `VERKAUFSPREIS` --> forward fill verwenden

# %%
data_2023_unique["VERKAUFSPREIS"] = data_2023_unique["VERKAUFSPREIS"].ffill()
data_2023_unique
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0       Whisky    USA         5645.0    RE_2023_5645          16.0
# 1       Whisky     EU         7994.0    RE_2023_7994         193.0
# 2       Whisky    USA         3190.0    RE_2023_3190         126.0
# 3       Whisky    USA          790.0     RE_2023_790         171.0
# 4          Rum    USA         9975.0    RE_2023_9975          41.0
# ...        ...    ...            ...             ...           ...
# 10922   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923     Wein     EU         5325.0    RE_2023_5325         253.0
# 10924   Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925     Wein     EU         5481.0    RE_2023_5481          19.0
# 10926   Whisky    USA         2523.0    RE_2023_2523         114.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0           128.95                5.0         128.95         -6.01
# ...

# %% [markdown]
# - befülle die NaN Werte mit dem `nachstehenden` nicht NaN-Wert in der Column `EINKAUFPREIS` --> backward fill verwenden

# %%
data_2023_unique["EINKAUFPREIS"] = data_2023_unique["EINKAUFPREIS"].bfill()
data_2023_unique
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0       Whisky    USA         5645.0    RE_2023_5645          16.0
# 1       Whisky     EU         7994.0    RE_2023_7994         193.0
# 2       Whisky    USA         3190.0    RE_2023_3190         126.0
# 3       Whisky    USA          790.0     RE_2023_790         171.0
# 4          Rum    USA         9975.0    RE_2023_9975          41.0
# ...        ...    ...            ...             ...           ...
# 10922   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923     Wein     EU         5325.0    RE_2023_5325         253.0
# 10924   Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925     Wein     EU         5481.0    RE_2023_5481          19.0
# 10926   Whisky    USA         2523.0    RE_2023_2523         114.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0           128.95                5.0         128.95         -6.01
# ...

# %% [markdown]
# - schaue dir die Daten mit der help-function `info` an

# %%
data_2023_unique.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10079 entries, 0 to 10926
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GETRAENK           10066 non-null  str
#  1   REGION             10077 non-null  str
#  2   BESTELLNUMMER      10079 non-null  float64
#  3   RECHNUNGSNUMMER    10079 non-null  str
#  4   KUNDENNUMMER       10079 non-null  float64
#  5   LISTENPREIS        10079 non-null  float64
#  6   RABATT_IN_PROZENT  10079 non-null  float64
#  7   VERKAUFSPREIS      10079 non-null  float64
#  8   RABATT_PREIS       10079 non-null  float64
#  9   EINKAUFPREIS       10079 non-null  float64
#  10  VK_PERIS_IN_USD    10079 non-null  float64
# dtypes: float64(8), str(3)
# memory usage: 944.9 KB

# %% [markdown]
# ### c) Datenbearbeitung Wiederholung
# - setze einen Filter von dem Dataframe `data_2023_neu_unique`
# - durch den Filter sollen `alle` Einträge deren `BESTELLNUMMER` zwischen `10` und `20` ist angezeigt werden
# <br><br> rows 11

# %%
data_2023_filtered = data_2023_unique.copy()

data_2023_filtered = data_2023_filtered[(data_2023_unique["BESTELLNUMMER"] >= 10) & (data_2023_unique["BESTELLNUMMER"] <= 20)]
data_2023_filtered
# Out:
#         GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 288       Whisky  Asien           15.0      RE_2023_15         137.0
# 1055      Whisky     EU           10.0      RE_2023_10         296.0
# 2693        Wein  Asien           19.0      RE_2023_19          84.0
# 3307      Whisky    USA           11.0      RE_2023_11         278.0
# 3461  Champagner  Asien           17.0      RE_2023_17          40.0
# 3783      Whisky    USA           20.0      RE_2023_20         287.0
# 4132      Whisky     EU           18.0      RE_2023_18          87.0
# 7340  Champagner     EU           12.0      RE_2023_12          85.0
# 7966        Wein     EU           14.0      RE_2023_14         279.0
# 9319      Whisky     EU           16.0      RE_2023_16         169.0
# 9443        Wein    USA           13.0      RE_2023_13          37.0
#
#       LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 288        138.20                0.0         138.20          0.00
# ...

# %% [markdown]
# - entferne alle rows mit den Kundennummern aus der Aufgabe vorher mittels `isin`
# <br><br> rows 9.720

# %%
customer_list = data_2023_filtered["KUNDENNUMMER"]
data_2023_unique = data_2023_unique[~data_2023_unique["KUNDENNUMMER"].isin(customer_list)]
data_2023_unique
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0       Whisky    USA         5645.0    RE_2023_5645          16.0
# 1       Whisky     EU         7994.0    RE_2023_7994         193.0
# 2       Whisky    USA         3190.0    RE_2023_3190         126.0
# 3       Whisky    USA          790.0     RE_2023_790         171.0
# 4          Rum    USA         9975.0    RE_2023_9975          41.0
# ...        ...    ...            ...             ...           ...
# 10922   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923     Wein     EU         5325.0    RE_2023_5325         253.0
# 10924   Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925     Wein     EU         5481.0    RE_2023_5481          19.0
# 10926   Whisky    USA         2523.0    RE_2023_2523         114.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0           128.95                5.0         128.95         -6.01
# ...

# %% [markdown]
# - sortiere die Daten einmal nach der `KUNDENNUMMER`

# %%
data_2023_unique.sort_values("KUNDENNUMMER")
# Out:
#         GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 53    Champagner    USA         6312.0    RE_2023_6312           1.0
# 5563        Wein     EU         2841.0    RE_2023_2841           1.0
# 3128      Whisky     EU         1280.0    RE_2023_1280           1.0
# 6617      Whisky     EU         1079.0    RE_2023_1079           1.0
# 1717        Wein  Asien         2496.0    RE_2023_2496           1.0
# ...          ...    ...            ...             ...           ...
# 3031      Whisky  Asien         7524.0    RE_2023_7524         299.0
# 3901      Whisky    USA         2073.0    RE_2023_2073         299.0
# 11        Whisky     EU         9231.0    RE_2023_9231         299.0
# 8903         Rum     EU         2049.0    RE_2023_2049         299.0
# 49        Whisky    USA         1942.0    RE_2023_1942         299.0
#
#       LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 53         166.26                0.0         166.26          0.00
# ...

# %% [markdown]
# - sortiere die Daten nach zwei Kriterien (das erste ist `GETRAENK`und das zweite ist `BESTELLNUMMER`)
#     - `GETRAENK` wird **absteigend** und
#     . `BESTELLNUMMER` wird **aufsteigend** sortiert

# %%
data_2023_unique.sort_values(by=["GETRAENK", "BESTELLNUMMER"], ascending=[False, True])
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 6224    Whisky     EU            0.0       RE_2023_0          26.0
# 10638   Whisky     EU            1.0       RE_2023_1          86.0
# 174     Whisky    USA            6.0       RE_2023_6         215.0
# 8254    Whisky  Asien            9.0       RE_2023_9         286.0
# 6139    Whisky     EU           21.0      RE_2023_21         104.0
# ...        ...    ...            ...             ...           ...
# 1041       NaN     EU        10059.0   RE_2023_10059          15.0
# 3001       NaN     EU        10062.0   RE_2023_10062          56.0
# 10772      NaN     EU        10064.0   RE_2023_10064          62.0
# 10007      NaN    USA        10066.0   RE_2023_10066          56.0
# 2727       NaN  Asien        10069.0   RE_2023_10069          50.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 6224         88.37                0.0          88.37          0.00
# ...

# %% [markdown]
# ## Aufgabe 4: Datenzusammenführen
# ### a) führe die Daten `data_2020, data_2021, data_2022 **und** data_2023_neu_unique` zusammen
#
# #### fasse die Daten sinnvoll zusammen (Vorbereitung)
# - schreibe eine Funktion um die Datensätze in die gleiche Columns umzuwandeln und erstelle jeweile neue Datframes mit dem Titel:
#     - data_2020_n
#     - data_2021_n
#     - data_2022_n
# - Die Einzelteile der Funktion wurden in den vorherigen Aufgaben schon definiert

# %%
#Gottlose Aufgabenstellung??????????????????

def normalize_df(df):
    new_df = df.copy()

    new_df.drop("Unnamed: 0", axis=1, inplace=True)
    new_df.columns = (new_df.columns.str.upper()
                      .str.replace(" ", "_")
                      .str.replace("Ä", "AE")
                      .str.replace("Ö", "OE")
                      .str.replace("Ü", "UE")
                      .str.replace("ß", "SS")
                      )
    return new_df

data_2020_n = normalize_df(df_2020)
data_2021_n = normalize_df(df_2021)
data_2022_n = normalize_df(df_2022)

data_2020_n.columns.tolist() == data_2021_n.columns.tolist() == data_2022_n.columns.tolist() == data_2023_unique.columns.tolist()
# Out:
# True

# %% [markdown]
# - benutze für das zusammenführen einmal `concat` und erstelle einen neuen Dataframes `data_all`
# <br><br> Lösung *25079 rows × 11 columns*

# %%
#ignore_index = True da sonst probleme mit der indexierung entsteht
data_all = pd.concat([data_2020_n, data_2021_n, data_2022_n, data_2023_unique], ignore_index=True)
data_all.shape
# Out:
# (24720, 11)

# %% [markdown]
# - benutze hierfür einmal `append`
# <br><br> Lösung *25079 rows × 11 columns*

# %%
#data_2020_n.append([data_2021_n, data_2022_n, data_2023_unique],ignore_index=True)
#Gibts in dieser pandas version wohl nicht mehr

# %% [markdown]
# # `**ACHTUNG** APPEND NORMALERWEISE NICHT VERWENDEN`
# ## append wird in zukünftigen Versionen nicht mehr funktionieren

# %% [markdown]
# - benutze für das zusammenführen `merge`
# <br><br> Lösung *25079 rows × 11 columns*

# %%
# das ergibt einfach keinen sinn
# man merged nur wenn man einen eindeutigen key hat (id) aber das haben wir hier nicht
# wirklich niemals jemand

temp_df_20_21 = pd.merge(data_2020_n, data_2021_n, how="outer")
temp_df_22_23 = pd.merge(data_2022_n, data_2023_unique, how="outer")
temp_df_20_23 = pd.merge(temp_df_20_21, temp_df_22_23, how="outer")

temp_df_20_23
# Out:
#          GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0      Champagner  Asien            3.0       RE_2021_3          69.0
# 1      Champagner  Asien            4.0       RE_2022_4         163.0
# 2      Champagner  Asien            7.0       RE_2020_7          97.0
# 3      Champagner  Asien           33.0      RE_2022_33         182.0
# 4      Champagner  Asien           70.0      RE_2021_70          30.0
# ...           ...    ...            ...             ...           ...
# 24715         NaN    USA        10015.0   RE_2023_10015          58.0
# 24716         NaN    USA        10017.0   RE_2023_10017          61.0
# 24717         NaN    USA        10048.0   RE_2023_10048           5.0
# 24718         NaN    USA        10058.0   RE_2023_10058          23.0
# 24719         NaN    USA        10066.0   RE_2023_10066          56.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# ...

# %% [markdown]
# - benutze für das zusammenführen der Daten `join`
# - funktioniert das?

# %%
#ergibt noch weniger sinn weil man automatisch über den index joined => sorgt dafür, dass die einträge mit den selben indexen einfach überschrieben werden
data_2020_n.join(data_2021_n, how="outer", lsuffix="_2020", rsuffix="_2021")
# Out:
#      GETRAENK_2020 REGION_2020  BESTELLNUMMER_2020 RECHNUNGSNUMMER_2020  \
# 0              Rum       Asien                 0.0            RE_2020_0
# 1             Wein          EU                 1.0            RE_2020_1
# 2             Wein       Asien                 2.0            RE_2020_2
# 3           Whisky         USA                 3.0            RE_2020_3
# 4           Whisky          EU                 4.0            RE_2020_4
# ...            ...         ...                 ...                  ...
# 4995           NaN         NaN                 NaN                  NaN
# 4996           NaN         NaN                 NaN                  NaN
# 4997           NaN         NaN                 NaN                  NaN
# 4998           NaN         NaN                 NaN                  NaN
# 4999           NaN         NaN                 NaN                  NaN
#
#       KUNDENNUMMER_2020  LISTENPREIS_2020  RABATT_IN_PROZENT_2020  \
# ...

# %% [markdown]
# ### b) Newsletter Daten
# - importiere die Dataframes `news` von den Jahren 2020 bis 2023 jeweils in einer eigenen Variabel

# %%
news_origin_2020 = pd.read_excel("ressources/news_2020.xlsx")
news_origin_2021 = pd.read_csv("ressources/news_2021.csv", sep="\t")
news_origin_2022 = pd.read_csv("ressources/news_2022.csv", sep="\t")
news_origin_2023 = pd.read_csv("ressources/news_2023.csv", sep="\t")

print(news_origin_2020.columns)
print(news_origin_2021.columns)
print(news_origin_2022.columns)
print(news_origin_2023.columns)
# Out:
# Index(['Kd.Nr', 'Newsletter_1_Cupon_2020', 'Newsletter_2_Cupon_2020',
#        'Newsletter_3_Cupon_2020', 'Newsletter_4_Cupon_2020',
#        'Newsletter_5_Cupon_2020', 'Newsletter_6_Cupon_2020',
#        'Newsletter_7_Cupon_2020', 'Newsletter_8_Cupon_2020',
#        'Newsletter_9_Cupon_2020', 'Newsletter_10_Cupon_2020',
#        'Newsletter_11_Cupon_2020', 'Newsletter_12_Cupon_2020'],
#       dtype='str')
# Index(['Unnamed: 0', 'Newsletter_1_Cupon_2021', 'Newsletter_2_Cupon_2021',
#        'Newsletter_3_Cupon_2021', 'Newsletter_4_Cupon_2021',
#        'Newsletter_5_Cupon_2021', 'Newsletter_6_Cupon_2021',
#        'Newsletter_7_Cupon_2021', 'Newsletter_8_Cupon_2021',
#        'Newsletter_9_Cupon_2021', 'Newsletter_10_Cupon_2021',
#        'Newsletter_11_Cupon_2021', 'Newsletter_12_Cupon_2021', 'Nummer_Kunde'],
#       dtype='str')
# Index(['KD_NEWS_KEY', 'Newsletter_1_Cupon_2022', 'Newsletter_2_Cupon_2022',
#        'Newsletter_3_Cupon_2022', 'Newsletter_4_Cupon_2022',
# ...

# %% [markdown]
# - verändere den Index im Dataframe `news_2020`
# - der neue Index soll die `Kd.Nr` sein

# %%
test = news_origin_2020.set_index(keys="Kd.Nr", inplace=False, drop=True).copy()
test
# Out:
#       Newsletter_1_Cupon_2020 Newsletter_2_Cupon_2020 Newsletter_3_Cupon_2020  \
# Kd.Nr
# 33                       nein                      ja                    nein
# 91                         ja                    nein                    nein
# 23                       nein                      ja                      ja
# 16                       nein                    nein                    nein
# 19                       nein                      ja                    nein
# 70                       nein                    nein                    nein
# 51                       nein                    nein                      ja
# 67                       nein                    nein                    nein
# 3                        nein                    nein                      ja
# 4                        nein                    nein                      ja
# 32                         ja                    nein                    nein
# ...

# %% [markdown]
# - führe die Newsletter Dataframe aus den Jahren `2020, 2021, 2022` zusammen
# - gebe nur die Kunden wieder, welche in allen 3 Datensätzen enthalten sind
# <br><br> Lösung *24 rows × 38 columns*

# %%
newsletter_all = (
    news_origin_2020
    .merge(news_origin_2021, how="inner", left_on="Kd.Nr", right_on="Unnamed: 0")
    .merge(news_origin_2022, how="inner", left_on="Kd.Nr", right_on="KD_NEWS_KEY")
)
newsletter_all.shape

# Habe mehrere Lösungswege probiert, kp wie er auf 24 Einträge kommt, ich komme immer auf 21
# Out:
# (24, 40)

# %% [markdown]
# - führe die Newsletter Dataframes aus den Jahren `2023, 2022` zusammen
# - spiele dabei alle Werte von 2022 an den Dataframe von 2023 dran
# - verwende `merge` für das zusammen führen
# <br><br> Lösung *240 rows × 25 columns*

# %%
#sollten 26 columns sein aber ist an sich für diese aufgabe eh der irrelevante teil
#abgesehen davon ist die aufgabe cursed -> es gibt 2 schein-id`s die sich immer um +1 unterscheiden
newsletter_merged = news_origin_2023.merge(
    news_origin_2022,
    on="KD_NEWS_KEY",
    how="left"
)
newsletter_merged
# Out:
#      Unnamed: 0 Newsletter_1_Cupon_2023 Newsletter_2_Cupon_2023  \
# 0            42                    nein                    nein
# 1             2                    nein                    nein
# 2           188                    nein                    nein
# 3           216                      ja                    nein
# 4           231                    nein                    nein
# ..          ...                     ...                     ...
# 235         254                    nein                    nein
# 236         201                    nein                    nein
# 237         165                    nein                    nein
# 238           4                    nein                    nein
# 239          82                    nein                    nein
#
#     Newsletter_3_Cupon_2023 Newsletter_4_Cupon_2023 Newsletter_5_Cupon_2023  \
# 0                      nein                    nein                    nein
# ...

# %% [markdown]
# - schreibe ***alle*** `news_data` in einen neuen Dataframes `news_all_years`
#     - was kann ich verwenden, wenn ich `nicht merge` verwenden möchte. Begründe es kurz
# - gebe nur eine `Kundennummer` in dem Dataframe als Columnnamen an
# - **Tipp** reset index bei dem Dataframe `news_2020`
# <br><br> Ergebnis 284 rows × 49 columns

# %%
news_origin_2020 = news_origin_2020.rename(columns={"Kd.Nr": "Kd.Nr"})
news_origin_2021 = news_origin_2021.rename(columns={"Unnamed: 0": "Kd.Nr"})
news_origin_2022 = news_origin_2022.rename(columns={"KD_NEWS_KEY": "Kd.Nr"})
news_origin_2023 = news_origin_2023.rename(columns={"Unnamed: 0": "Kd.Nr"})

news_origin_2021.drop(columns="Nummer_Kunde", inplace=True)
news_origin_2023.drop(columns="KD_NEWS_KEY", inplace=True)

news_all_years = (news_origin_2020
                  .merge(news_origin_2021, how="outer", on="Kd.Nr")
                  .merge(news_origin_2022, how="outer", on="Kd.Nr")
                  .merge(news_origin_2023, how="outer", on="Kd.Nr"))


news_all_years
# Out:
#      Kd.Nr Newsletter_1_Cupon_2020 Newsletter_2_Cupon_2020  \
# 0        0                     NaN                     NaN
# 1        1                      ja                      ja
# 2        2                     NaN                     NaN
# 3        3                    nein                    nein
# 4        4                    nein                    nein
# ..     ...                     ...                     ...
# 275    295                     NaN                     NaN
# 276    296                     NaN                     NaN
# 277    297                     NaN                     NaN
# 278    298                     NaN                     NaN
# 279    299                     NaN                     NaN
#
#     Newsletter_3_Cupon_2020 Newsletter_4_Cupon_2020 Newsletter_5_Cupon_2020  \
# 0                       NaN                     NaN                     NaN
# 1                      nein                    nein                      ja
# ...

# %% [markdown]
# - füge über die Kundennummern die Daten aus `news_all_years` an die Daten aus `data_all` an
# - und speicher diese in dem Datensatz `data_merged_save`
# <br><br> Ergebnis 25079 rows × 59 columns

# %%
data_merged_save = pd.merge(data_all, news_all_years, how="outer", left_on="KUNDENNUMMER",right_on="Kd.Nr")
data_merged_save
# Out:
#          GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0             NaN    NaN            NaN             NaN           NaN
# 1          Whisky    USA           59.0      RE_2020_59           1.0
# 2          Whisky    USA           62.0      RE_2020_62           1.0
# 3            Wein  Asien           88.0      RE_2020_88           1.0
# 4            Wein     EU          206.0     RE_2020_206           1.0
# ...           ...    ...            ...             ...           ...
# 24720         Rum     EU         2049.0    RE_2023_2049         299.0
# 24721  Champagner    USA         9894.0    RE_2023_9894         299.0
# 24722        Wein     EU         9703.0    RE_2023_9703         299.0
# 24723      Whisky  Asien           98.0      RE_2023_98         299.0
# 24724      Whisky     EU         1360.0    RE_2023_1360         299.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# ...

# %% [markdown]
# ## Aufgabe 5: Daten in eine CSV und Excel schreiben
#
# - speichere den Dataframe `data_merged_save` in einer Excel Datei
#     - erstelle hierfür einen Ordner in der du die Excel speichern willst
#     - gebe dem Excel den Sheet Namen `news_2023` mit

# %%
data_merged_save.to_excel("output/merged_data.xlsx", index=False, sheet_name="news_2023")

# %% [markdown]
# - speichere den Dataframe `data_merged_save` äquivalent in einer csv Datei
# - gebe den `Seperator` und das `Encoding` verfahren mit

# %%
data_merged_save.to_csv("output/merged_data.csv", index=False, encoding="utf-8", sep="\t")

# %% [markdown]
# ## Aufgabe 6: Datenselektion
# ### a) selektion mittels Datenzusammenführen
# - erstelle `nur` einen Dataframe von allen Kunden aus den Daten `data_2020`, welche auch Produkte in den anderen `data_2021, data_2022 und data_2023_neu_unique` haben
# <br><br> Ergebnis 11.653 rows × 11 columns

# %%
# concat # Ich verstehe die aufgabe nicht
# Ich erstelle ein Dataframe mit allen Kundennummern aus 2021-2023
kunden_pool = (
    pd.concat(
        [
            data_2021_n[["KUNDENNUMMER"]],
            data_2022_n[["KUNDENNUMMER"]],
            data_2023_unique[["KUNDENNUMMER"]],
        ],
        ignore_index=True
    )
    .drop_duplicates()
)
kunden_pool
# Out:
#        KUNDENNUMMER
# 0             114.0
# 1              57.0
# 2             125.0
# 3              69.0
# 4              71.0
# ...             ...
# 13604         263.0
# 13607         254.0
# 13633         286.0
# 13790         292.0
# 13803         261.0
#
# [295 rows x 1 columns]

# %%
#merge
merge_2020 = data_2020_n.merge(
    kunden_pool,
    on="KUNDENNUMMER",
    how="inner"
).drop_duplicates(subset="KUNDENNUMMER")

merge_2020
# Out:
#        GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0           Rum  Asien              0       RE_2020_0            27
# 1          Wein     EU              1       RE_2020_1            87
# 2          Wein  Asien              2       RE_2020_2            76
# 3        Whisky    USA              3       RE_2020_3            44
# 4        Whisky     EU              4       RE_2020_4            25
# ..          ...    ...            ...             ...           ...
# 340      Whisky  Asien            340     RE_2020_340            19
# 365        Wein    USA            365     RE_2020_365            40
# 419  Champagner     EU            419     RE_2020_419            64
# 445      Whisky    USA            445     RE_2020_445            12
# 576      Whisky  Asien            576     RE_2020_576            65
#
#      LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0          86.23                  0          86.23          0.00
# ...

# %% [markdown]
# ### b) nach Selektionskriterien in Dataframes
# - selktiere den Dataframe `data_all` nach den folgenden Kriterien
# #### Der Dataframe soll endeweder:
# - `nur` die `REGION EU oder Asien` und
# - nur Kunden mit einer `KUNDENNUMMER grösser/gleich 50` und
# - das Getränk darf `nicht gleich Champagner` sein und
# - es wurde kein Rabatt gewärt (`= 0`)
# <br><br> **oder** <br><br>
# - die `BESTELLNUMMER` enthält die Zahl 1 an irgendeiner Stelle z.B. `(1, 10, 21 ..)`
# <br><br> Ergebnis 15.772 rows × 11 columns

# %%
filter_data_all = data_all[
    (
        (
            (data_all["REGION"].isin(["EU", "Asien"])) &
            (data_all["KUNDENNUMMER"] >= 50) &
            (data_all["GETRAENK"] != "Champagner") &
            (data_all["RABATT_IN_PROZENT"] == 0)
        )
        |
        (
            data_all["BESTELLNUMMER"]
            .astype(str)
            .str.contains("1", regex=False)
        )
    )
]

filter_data_all
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 1         Wein     EU            1.0       RE_2020_1          87.0
# 2         Wein  Asien            2.0       RE_2020_2          76.0
# 9       Whisky  Asien            9.0       RE_2020_9          85.0
# 10         Rum     EU           10.0      RE_2020_10          41.0
# 11         Rum     EU           11.0      RE_2020_11          82.0
# ...        ...    ...            ...             ...           ...
# 24713      Rum    USA         2119.0    RE_2023_2119          31.0
# 24714   Whisky     EU         3067.0    RE_2023_3067         270.0
# 24715   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 24716     Wein     EU         5325.0    RE_2023_5325         253.0
# 24718     Wein     EU         5481.0    RE_2023_5481          19.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 1           182.93                0.0         182.93           0.0
# ...

# %% [markdown]
# #### selktiere den Dataframe `data_2023`
# - es sollen nur rows angezeigt werden, welche
#     - `kein Wert` in der Rechnungsnummer haben **`und`**
#     - `ein Wert` in der Kundennummer haben
# <br><br> Ergebnis 8 rows

# %%
filter_data_2023 = data_2023_unique[
    (
        data_2023_unique["RECHNUNGSNUMMER"].isna()
    )
    &
    (
        ~data_2023_unique["KUNDENNUMMER"].isna()
    )
]
filter_data_2023

# codelogik ist korrekt aber ergebnis weicht mal wieder ab
# Out:
# Empty DataFrame
# Columns: [GETRAENK, REGION, BESTELLNUMMER, RECHNUNGSNUMMER, KUNDENNUMMER, LISTENPREIS, RABATT_IN_PROZENT, VERKAUFSPREIS, RABATT_PREIS, EINKAUFPREIS, VK_PERIS_IN_USD]
# Index: []

# %% [markdown]
# - es sollen nur rows angezeigt werden, welche
#     - `ein Wert` in der Rabattcolumn haben **`oder`**
#     - `kein Wert` in der Verkaufspreis
# <br><br> Ergebnis 10.920 rows × 12 columns

# %%
filter_data_2023 = data_2023_unique[
    (
        ~data_2023_unique["RABATT_IN_PROZENT"].isna()
    )
    |
    (
        data_2023_unique["VERKAUFSPREIS"].isna()
    )
]

filter_data_2023
# Out:
#       GETRAENK REGION  BESTELLNUMMER RECHNUNGSNUMMER  KUNDENNUMMER  \
# 0       Whisky    USA         5645.0    RE_2023_5645          16.0
# 1       Whisky     EU         7994.0    RE_2023_7994         193.0
# 2       Whisky    USA         3190.0    RE_2023_3190         126.0
# 3       Whisky    USA          790.0     RE_2023_790         171.0
# 4          Rum    USA         9975.0    RE_2023_9975          41.0
# ...        ...    ...            ...             ...           ...
# 10922   Whisky  Asien         4659.0    RE_2023_4659         267.0
# 10923     Wein     EU         5325.0    RE_2023_5325         253.0
# 10924   Whisky    USA         9793.0    RE_2023_9793         152.0
# 10925     Wein     EU         5481.0    RE_2023_5481          19.0
# 10926   Whisky    USA         2523.0    RE_2023_2523         114.0
#
#        LISTENPREIS  RABATT_IN_PROZENT  VERKAUFSPREIS  RABATT_PREIS  \
# 0           128.95                5.0         128.95         -6.01
# ...
