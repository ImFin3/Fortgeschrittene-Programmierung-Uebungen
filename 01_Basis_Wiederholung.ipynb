# %% [markdown]
# # Aufgabenblatt 1: Einstieg
# - importiere numpy

# %%
import numpy as np

# %% [markdown]
# ## Aufgabe 1: Datenstrukturen

# %% [markdown]
# Für die folgenden Subaufgaben und der Darstellung von Listen, Tupel und Dictionaire gibt es jeweils zwei verschiedene Schreibweisen (mittels `Funktion` und `Klammern`)
# <br>
# Speichere die Datenstrukturen jeweils in einer eigenen `Variable` und gebe diese mittels der **print** Funktion aus
# ### a) Liste
# - Erstelle eine `Liste` mit den Werten `3, 5, 8, 10, ab`
# - Schriebe die Liste in zwei Varianten

# %%
list1 = list((3,5,8,10,"ab"))
list2 = [3,5,8,10,"ab"]
print(list1)
print(list2)
# Out:
# [3, 5, 8, 10, 'ab']
# [3, 5, 8, 10, 'ab']

# %% [markdown]
# ### b) Tuple
# - Erstelle ein `Tupel` mit den Werten: `'Hallo', 'mein', 'Name', 'ist'`

# %%
tuple1 = tuple(("Hallo", "mein", "Name", "ist"))
tuple2 = ("Hallo", "mein", "Name", "ist")
print(tuple1)
print(tuple2)
# Out:
# ('Hallo', 'mein', 'Name', 'ist')
# ('Hallo', 'mein', 'Name', 'ist')

# %% [markdown]
# ### c) Dictonarie
# - Erstelle ein `Dictonarie`, welches einen Schlüssel hat `Name` und gebe diesem Werte mit *als String* und dem Schlüssel `Alter` ein Wert *als Integer*

# %%
dict1 = dict({"Name": "Kai", "Alter": 34})
dict2 = {"Name": "Kai", "Alter": 34}
print(dict1)
print(dict2)
# Out:
# {'Name': 'Kai', 'Alter': 34}
# {'Name': 'Kai', 'Alter': 34}

# %% [markdown]
# ## Aufgabe 2: print()
#
# ### a) help Function
# - Untersuche was die print Funktion kann

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %% [markdown]
# ### b) Ausgabe von print()
# Gebe als Output: die folgenden Strings genau wieder:
# - Python programmieren macht wirklich Spass!

# %%
print("Python programmieren macht wirklich Spass!")
# Out:
# Python programmieren macht wirklich Spass!

# %% [markdown]
# - Er sagt: "Das ist wirklich einfach"

# %%
print(f"Er Sagt: \"Das ist wirklich einfach\"")
# Out:
# Er Sagt: "Das ist wirklich einfach"

# %% [markdown]
# - I'm board by this task :)

# %%
print("I'm bored by this task :)")
# Out:
# I'm bored by this task :)

# %% [markdown]
# Die Ausgabe `mit backslash lösen` Der Ausruck soll mit einfachen Print Simikollons geschrieben werden
# - I'm board by this task :)

# %%
print('I\'m bored by this task :)')
# Out:
# I'm bored by this task :)

# %% [markdown]
# - Meine Bachelornote nach 3 Jahren soll eine 1,5 sein
# - `die 1,5 soll eine Variable sein` sodass die Note in der Variable ausgetausscht werden kann. Benutze einmal eine Funktion und einmal die Variable in einem String

# %%
note = 1.5
print(f"Meine Bachelornote nach 3 Jahren soll eine {note} sein.")
# Out:
# Meine Bachelornote nach 3 Jahren soll eine 1.5 sein.

# %% [markdown]
# ### c) erstelle einen eigenen String
# - Erstelle einen Satz aus mindestens 4 Wörten `und`
# - gebe dabei jedes Wort in einer eigenen Zeile an, mittels der print-Funktion.
# <br>
# **Tipp:** `Escape-Character`

# %%
print("Das\nwar\ndie\nAufgabe!")
# Out:
# Das
# war
# die
# Aufgabe!

# %% [markdown]
# ### d) Dateipfad
# - Gebe einen beliebigen Dateipfad an (z.B. `c:\test\name`) mittels print-Funktion aus. Dies wird später z.B. benötigt um Dateipfade zu speichern in Programmen

# %%
print("C:\\Users\\...\\Desktop\\UniRepos\\Fortgeschrittene Programmierung Übungen")
# Out:
# C:\Users\...\Desktop\UniRepos\Fortgeschrittene Programmierung Übungen

# %% [markdown]
# ### e) Variablenausgabe
# Erstelle die Variabeln;
# - die Variable `var_out_a` mit dem Wert `2` *und*
# - die Variable `var_out_b` mit dem Wert `5`
# - und gebe diese anschliessend nacheinander mit der print-Funktion aus `2 5`

# %%
var_out_a = 2
var_out_b = 5
print(f"{var_out_a} {var_out_b}")
# Out:
# 2 5

# %% [markdown]
# - Nun sollen die Variablen `var_out_a und var_out_b` mittels eines `Kommas getrennt` werden `2, 5` mittels eines Seperators

# %%
print(f"{var_out_a},{var_out_b}")
# Out:
# 2,5

# %% [markdown]
# - Welche alternative Schreibweise gibt es noch?

# %%
print(f"{var_out_a} , {var_out_b}")
# Out:
# 2 , 5

# %% [markdown]
# ## Aufgabe 3: Operatoren
# ### a) einfache mathematische Berechnungen
# Überlege dir vorab die Ergebnisse zu den folgenden Aufgaben und berechne diese
# - 4 + 6 / 2

# %%
print(f"{4 + 6 / 2}")
# Out:
# 7.0

# %% [markdown]
# - (4 + 6) / 2

# %%
print(f"{(4 + 6) / 2}")
# Out:
# 5.0

# %% [markdown]
# - 4 + (6 / 2)

# %%
print(f"{4 + (6 / 2)}")
# Out:
# 7.0

# %% [markdown]
# - Was ist der Restwert von dem `Modulo 3` von ``10``?

# %%
print(f"{10%3}")
# Out:
# 1

# %% [markdown]
# ### b) mathematische Berechnungen mittels Variabeln
# Überlege dir für die nachfolgende Aufgaben erst die einzelnen zwischen Ergebnisse und programmiere anschliessend die Lösungen. Gebe die einzelnen zwischen Lösungen mittels der print-Funktion aus.
#
# - Definiere eine Variable a `variable_a` mit dem Wert `20` und eine Variable b  `Variable_b` mit dem Wert `12` und addiere die beiden Variabeln in eine neue Variable `result_a_and_b`

# %%
variable_a = 20
variable_b = 12
result_a_and_b = variable_a + variable_b
print(result_a_and_b)
# Out:
# 32

# %% [markdown]
# - Führe anschliessend auf die Variable `result_a_and_b` eine Ganzahldevision mit der Variable `ganzahldevision` und dem Wert `3` aus
# - speicher das berechnete Ergebnis in der Variable `result_c`

# %%
ganzzahldivision = 3
result_c = result_a_and_b // ganzzahldivision
print(result_c)
# Out:
# 10

# %% [markdown]
# - mutpliziere den Wert von `result_c` mit dem Wert `1,5` über die Variable `variable_multiplikator`
# - Das Ergebnis soll in der Variable `result_d` gespeichert werden

# %%
variable_multiplikator = 1.5
result_d = result_c * variable_multiplikator
print(result_d)
# Out:
# 15.0

# %% [markdown]
# ### c) Variablenveränderung
# - erstelle die Variable `number` mit dem Wert 0
# - gebe diese anschliessend aus mit dem Text: `befor operator: `
# - anschliessend soll die Variable `number` mit dem zusammengesetzten Operator +4 zusamengesetzt werden --> benutze den Operator direct
# - schreibe in die print Funktion, dein erwartetes Ergebnis und gebe das richtige Ergebnis wie `Meine Annahme = 4; Das Ergebnis nach Operartor ist:  4`

# %%
number = 0
print(f"Bevor Operator: {number}")
number+=4
print(f"Meine Annahme: 4; Das Ergebnis nach Operator ist: {number}")
# Out:
# Bevor Operator: 0
# Meine Annahme: 4; Das Ergebnis nach Operator ist: 4

# %% [markdown]
# - Wie ist eine äquivalente Schreibweise? --> Getrennt oder zusammenfassen des Operators

# %%
number = 0
number = number + 4
print(number)
# Out:
# 4

# %% [markdown]
# ### d) weitere mathematische Basis-Aufgaben
#
# Berechne erst im Kopf die Ergebnisse für die folgenden `zusammengesetzten` Operatoren zu den jeweiligen Teilschritten.
# <br>
# <br>
# `Achtung:`
# - Gebe jeden Teilschritt einzelnt mit print() aus
# - verwende/ändere immer die `gleiche` fortlaufende operatoren_variable
# - **operatoren_variable** ist gleich `10`

# %%
operator_variable = 10
print(operator_variable)
# Out:
# 10

# %% [markdown]
# - **mutlpiziere** die operatoren_variable mit `3`

# %%
operator_variable *= 3
print(operator_variable)
# Out:
# 30

# %% [markdown]
# - **subtrahiere** die operatoren_variable mit der Zahl `12`

# %%
operator_variable -= 12
print(operator_variable)
# Out:
# 18

# %% [markdown]
# - **dividiere** die operatoren_variable durch `3`

# %%
operator_variable /= 3
print(operator_variable)
# Out:
# 6.0

# %% [markdown]
# - **berechne** das Modulo `4` aus der operatoren_variable

# %%
operator_variable %= 4
print(operator_variable)
# Out:
# 2.0

# %% [markdown]
# - **addiere** `number` aus Aufgabe c mit der operatoren_variable und gebe das Endergebnis aus

# %%
operator_variable += number
print(f"operator_variable = {operator_variable}")
# Out:
# operator_variable = 6.0

# %% [markdown]
# ### e) boolesche Operatoren
# Was kommt bei den verschiedenen Kombinationen als boolischen Wert raus? `Begünde` mittels Boolischer Matrix aus Präsentationsfolie 42 dein Ergebnis.
# - Was kommt bei bool(0) für ein Ergebnis raus

# %%
print(bool(0))
# Out:
# False

# %%
# Binärsystem -> 0 => False ; 1 => True

# %% [markdown]
# Berechne dies für die folgenden Kombinationen:
# - True and True or False

# %%
print((True and True or False))
# Out:
# True

# %% [markdown]
# - True and True and False

# %%
print((True and True and False))
# Out:
# False

# %% [markdown]
# - True and 1 and 2

# %%
print((True and 1 and 2))
# Out:
# 2

# %% [markdown]
# - True or 1 and 2

# %%
print(True or 1 and 2)
# Out:
# True

# %% [markdown]
# - (True or 1) and 2

# %%
print(((True or 1) and 2))
# Out:
# 2

# %% [markdown]
# - [] and 1 and 2

# %%
print(([] and 1 and 2))
# Out:
# []

# %% [markdown]
# - [] and 1 and np.nan

# %%
print(([] and 1 and np.nan))
# Out:
# []

# %% [markdown]
# - [] and 1 or np.nan

# %%
print([] and 1 or np.nan)
# Out:
# nan

# %% [markdown]
# - [] and (1 or np.nan)

# %%
print([] and (1 or np.nan))
# Out:
# []

# %% [markdown]
# - 1>2>3

# %%
print(1>2>3)
# Out:
# False

# %% [markdown]
# - 1<2>3

# %%
print(1<2>3)
# Out:
# False

# %% [markdown]
# - 1<2<3

# %%
print(1<2<3)
# Out:
# True
